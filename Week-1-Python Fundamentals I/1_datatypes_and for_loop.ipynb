# %% [markdown]
# ### Datatypes for Python

# %%
revenue = 50
print(revenue)
# Out:
# 50

# %%
type(revenue)
# Out:
# int

# %%
expenses_description =" I'd like buy things in mall"
expenses_description
# Out:
# " I'd like buy things in mall"

# %%
expenses_description =''' I'd like buy things in mall.
I'd like buy things in mall,I'd like buy things in mall'''
expenses_description
# Out:
# " I'd like buy things in mall.\nI'd like buy things in mall,I'd like buy things in mall"

# %% [markdown]
# Naming is snake case : https://peps.python.org/pep-0008/

# %%
len(expenses_description)
# Out:
# 85

# %%
revenuses = [10,20,30]
expenses = [20,10,8]
for i in range(len(revenuses)):
    profit=revenuses[i]-expenses[i]
    print(profit)
# Out:
# -10
# 10
# 22

# %%
list_of_data = sum(revenuses)
list_of_data
# Out:
# 60

# %%
id(revenuses)
# Out:
# 1390281864000

# %% [markdown]
# Dictionaries

# %%
finance={'revenue':50,'expenses':40}
finance
# Out:
# {'revenue': 50, 'expenses': 40}

# %% [markdown]
# list of dictionaries

# %%
finance=[{'revenue':50,'expenses':40},
         {'revenue':50,'expenses':40},
         {'revenue':50,'expenses':40}]
finance
# Out:
# [{'revenue': 50, 'expenses': 40},
#  {'revenue': 50, 'expenses': 40},
#  {'revenue': 50, 'expenses': 40}]

# %%
finance={'Q1':{'revenue':50,'expenses':40},
         'Q2':{'revenue':50,'expenses':40},
         'Q3':{'revenue':50,'expenses':40}}

# %%
for quarter,data in finance.items():
    margin = data["revenue"]-data["expenses"]
    print(margin)
# Out:
# 10
# 10
# 10

# %% [markdown]
# Tuples : are immutable that is cannot change value after assgined

# %%
purple=(128,0,128) 
purple
# Out:
# (128, 0, 128)

# %%
purple[0]=120
purple
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 purple[0]=120
#       2 purple
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# You're tracking quiz scores for students in a Python cohort. Each student has taken 3 quizzes, and you want to figure out who's passing, who's topping, and the class average.
#
# ```
# students = {
#     "Aarav":   [85, 90, 78],
#     "Priya":   [72, 68, 75],
#     "Rohan":   [45, 52, 48],
#     "Sneha":   [95, 92, 98],
#     "Manish":  [60, 65, 70],
# }
# ```
#
# Each key is a student name, and each value is a list of 3 quiz scores (out of 100).
#
# Write code using for loops to do the following:
#
# 1. Calculate each student's average score and print it in this format:```Aarav: 84.33```
# 2. Classify each student based on their average:
#     80 and above → "Topper"
#     60 to 79 → "Pass"
#     Below 60 → "Needs improvement"
# 3. Find the topper of the class (highest average) and print their name and score.
# 4. Calculate the class average across all students.
#
# Expected output (roughly)
#
# ```
# === Student Averages ===
# Aarav: 84.33 - Topper
# Priya: 71.67 - Pass
# Rohan: 48.33 - Needs improvement
# Sneha: 95.00 - Topper
# Manish: 65.00 - Pass
#
# === Class Topper ===
# Sneha with average 95.00
#
# === Class Average ===
# 72.87
# ```

# %%
students = {
    "Aarav":   [85, 90, 78],
    "Priya":   [72, 68, 75],
    "Rohan":   [45, 52, 48],
    "Sneha":   [95, 92, 98],
    "Manish":  [60, 65, 70],
}

# %%
for name, data  in students.items():
    avg = sum(data)/3
    if(avg>80):
        print("Topper")
    elif(avg>65 and avg<79):
        print("Pass")
    else:
        print("Needs improvement")
    print(f" {name} : {avg:.2f}")
# Out:
# Topper
#  Aarav : 84.33
# Pass
#  Priya : 71.67
# Needs improvement
#  Rohan : 48.33
# Topper
#  Sneha : 95.00
# Needs improvement
#  Manish : 65.00

# %%
for name, data  in students.items():
    avg = sum(data)/3
    if(avg>80):
        print("Topper")
        print(f" {name} : {avg:.2f}")
# Out:
# Topper
#  Aarav : 84.33
# Topper
#  Sneha : 95.00

# %%
total_avg=0
for name, data  in students.items():
    avg = sum(data)/3
    total_avg+=avg
print(f"{total_avg/len(students):.2f}")
# Out:
# 72.86666666666667
